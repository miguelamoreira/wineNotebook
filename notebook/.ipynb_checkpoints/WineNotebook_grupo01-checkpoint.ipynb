# %% [markdown]
# # Análise de vinhos 🍷

# %% [markdown]
# ### Inteligência Artificial 2023/2024
# ### Grupo 1
# - Inês Rocha (40220247)
# - Miguela Moreira (40210256)
# - Sofia Cabral (40220195)

# %% [markdown]
# # ------------------------------------------------------------------------------

# %% [markdown]
# ## Sobre o dataset
# O dataset é composto por informações sobre características químicas de diferentes tipos de vinho, branco ou tinto.
# - Type: indica se o vinho é branco ou tinto;
# - Fixed acidity: a quantidade de ácidos não volatéis (g/L);
# - Volatile acidity: a quantidade de ácidos volatéis (g/L);
# - Citric acid: a quantidade de ácido cítrico (g/L);
# - Residual sugar: a quantidade de açúcar residual (g/L);
# - Chlorides: a quantidade de cloretos (g/L);
# - Free sulfur dioxide: a quantidade de dióxido de enxofre livre (mg/L);
# - Total sulfur dioxide: a quantidade total de dióxido de enxofre (mg/L);
# - Density: a densidade do vinho (g/cm³);
# - pH: o nível de pH do vinho;
# - Sulphates: a quantidade de sulfatos (g/L);
# - Alcohol: o teor alcoólico do vinho (%vol);
# - Quality: a avaliação do vinho (0-10)

# %% [markdown]
# # ------------------------------------------------------------------------------

# %% [markdown]
# # Análise de dados

# %%
# importação das bibliotecas principais
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn import tree
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score, r2_score, mean_absolute_error as mae, mean_squared_error as mse
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.svm import SVC
from sklearn.linear_model import LinearRegression
from xgboost.sklearn import XGBRegressor

# %%
# importação do dataset a ser utilizado
df = pd.read_csv('../dataset/VinhoClassReg.csv')

# %%
# visualização das primeiras linhas para compreender melhor a estrutura do dataset
df.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %%
# descobrir informação sobre as colunas que compõem o dataset (quantidade de linhas com valores e tipo de valores)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6487 non-null   float64
#  2   volatile acidity      6489 non-null   float64
#  3   citric acid           6494 non-null   float64
#  4   residual sugar        6495 non-null   float64
#  5   chlorides             6495 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6488 non-null   float64
#  10  sulphates             6493 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %% [markdown]
# ### Interpretação dos resultados:
# - Existem valores nulos nas colunas 'fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'pH' e 'sulphates';
# - A coluna 'type' está em formato objeto. É necessário proceder à conversão para formato númerico de modo a proceder à análise dos tipos de vinhos com os diferentes atributos e à criação dos modelos de classificação e de regressão.

# %%
# contagem dos valores nulos 
df.isnull().sum()
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %% [markdown]
# ### Interpretação dos resultados:
# - O atributo com maior número de linhas nulas ('fixed acidity') tem somente 10 linhas com valores nulos;
# - Podemos resolver o problema das linhas com valores nulos de duas formas distintas:
#   - Eliminação das linhas;
#   - Substituir os valores nulos pelo valor médio de cada uma das colunas.
# - Dado que o dataset é composto por 6497 linhas e o número de linhas com valores nulos nas diferentes colunas ser extremamente reduzido em comparação, vamos proceder à remoção dessas linhas.

# %%
# remoção de linhas com valores nulos
df = df.dropna()

# %%
# confirmação da remoção de linhas com valores nulos
df.isnull().sum()
# Out:
# type                    0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# ### Interpretação dos resultados:
# - Certificamo-nos que já não existem linhas com valores nulos no dataframe. Agora podemos passar à conversão dos valores da coluna 'type' para valores númericos. Podemos fazer esta conversão de duas formas:
#   - Através do método get_dummies();
#   - Através do LabelEncoder().
# - Uma vez que só existem dois tipos de vinho no nosso dataset - white ou red -, o método de conversão mais eficiente é o LabelEncoder.

# %%
# inicialização do LabelEncoder
label_encoder = LabelEncoder()

# %%
# conversão dos valores da coluna 'type' em valores númericos
df['type'] = label_encoder.fit_transform(df['type'])

# %%
# confirmação da conversão dos valores da coluna 'type' em valores númericos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6463 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6463 non-null   int64
#  1   fixed acidity         6463 non-null   float64
#  2   volatile acidity      6463 non-null   float64
#  3   citric acid           6463 non-null   float64
#  4   residual sugar        6463 non-null   float64
#  5   chlorides             6463 non-null   float64
#  6   free sulfur dioxide   6463 non-null   float64
#  7   total sulfur dioxide  6463 non-null   float64
#  8   density               6463 non-null   float64
#  9   pH                    6463 non-null   float64
#  10  sulphates             6463 non-null   float64
#  11  alcohol               6463 non-null   float64
#  12  quality               6463 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 706.9 KB

# %% [markdown]
# ### Interpretação dos resultados obtidos:
# - A conversão da coluna 'type' foi bem sucedida;
# - A partir de agora podemos analisar os dados de cada coluna e comparar dados entre colunas para compreender melhor como é que os valores dos atributos variam.

# %%
# estatísticas dos valores de cada uma das colunas do dataset
df.describe()
# Out:
#               type  fixed acidity  volatile acidity  citric acid  \
# count  6463.000000    6463.000000       6463.000000  6463.000000
# mean      0.753520       7.217755          0.339589     0.318758
# std       0.430995       1.297913          0.164639     0.145252
# min       0.000000       3.800000          0.080000     0.000000
# 25%       1.000000       6.400000          0.230000     0.250000
# 50%       1.000000       7.000000          0.290000     0.310000
# 75%       1.000000       7.700000          0.400000     0.390000
# max       1.000000      15.900000          1.580000     1.660000
#
#        residual sugar    chlorides  free sulfur dioxide  total sulfur dioxide  \
# count     6463.000000  6463.000000          6463.000000           6463.000000
# mean         5.443958     0.056056            30.516865            115.694492
# std          4.756852     0.035076            17.758815             56.526736
# ...

# %%
# distribuição dos valores de cada uma das colunas do dataset
df.hist(bins=20, figsize=(15, 10))
plt.suptitle('Distribuição das Características Químicas dos Vinhos')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Interpretação dos resultados obtidos:
# - Tirando os gráficos dos atributos 'type' e 'quality', os gráficos dos atributos apresentam todos uma zona preenchida com barras, representando a maior parte dos valores. No entanto, também se pode observar que estes gráficos aparentam ter valores, embora poucos, fora desta zona devido à escala do eixo do x;
# - Como se trata de um valor reduzido em comparação aos restantes valores, podemos eliminá-los sem prejudicar o resto da análise de dados e a criação dos modelos de classificação e de regressão

# %%
# função para remover os outliers de cada atributo
def remove_outliers(df):
    df_clean = df.copy()
    for col in df.select_dtypes(include=[np.number]).columns:
        mean = df[col].mean()
        std = df[col].std()
        cutoff = std * 3
        lower, upper = mean - cutoff, mean + cutoff
        df_clean = df_clean[(df_clean[col] >= lower) & (df_clean[col] <= upper)]
    return df_clean

df = remove_outliers(df)

# %%
# confirmação da remoção dos outliers (em números)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5955 entries, 1 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  5955 non-null   int64
#  1   fixed acidity         5955 non-null   float64
#  2   volatile acidity      5955 non-null   float64
#  3   citric acid           5955 non-null   float64
#  4   residual sugar        5955 non-null   float64
#  5   chlorides             5955 non-null   float64
#  6   free sulfur dioxide   5955 non-null   float64
#  7   total sulfur dioxide  5955 non-null   float64
#  8   density               5955 non-null   float64
#  9   pH                    5955 non-null   float64
#  10  sulphates             5955 non-null   float64
#  11  alcohol               5955 non-null   float64
#  12  quality               5955 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 651.3 KB

# %%
# confirmação da remoção dos outliers (em gráficos)
df.hist(bins=20, figsize=(15, 10))
plt.suptitle('Distribuição das Características Químicas dos Vinhos')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Interpretação dos resultados obtidos:
# - A remoção de outliers foi bem sucedida. Através do df.info() foi possível determinar que foram removidas 541 linhas, o que se traduz num valor ligeramente elevado de valores removidos. É importante considerar que esta remoção de outliers pode ter um impacto negativo na análise e na criação dos modelos;
# - Podemos agora proceder à análise dos atributos em relação ao tipo de vinho. Primeiro, faremos uma análise para evidenciar a correlação dos diferentes atributos com o tipo de vinho. De seguida, para facilitar a interpretação vamos analisar os valores dos diferentes atributos consoante cada tipo de vinho. Esta análise vai ser importante para a criação dos modelos de classificação.

# %%
# análise de correlação
plt.figure(figsize=(15, 10))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Mapa de Calor das Correlações entre Características')
plt.xlabel('Correlação')
plt.ylabel('Variáveis')
plt.show()

# %% [markdown]
# ### Interpretação dos resultados detalhados:
# - Existem 1583 linhas com dados referentes a vinhos brancos;
# - A maioria dos valores da coluna 'fixed acidity' varia entre 7.10 (25%) 9.20 (75%), sendo os valores mínimo de 4.60 e máximo de 15.90;
# - A maioria dos valores da coluna 'volatile acidity' varia entre 0.39 (25%) 0.64 (75%), sendo os valores mínimo de 0.12 e máximo de 1.33;
# - A maioria dos valores da coluna 'citric acid' varia entre 0.10 (25%) 0.43 (75%), sendo os valores mínimo de 0.00 e máximo de 1.00;
# - A maioria dos valores da coluna 'residual sugar' varia entre 1.90 (25%) 2.60 (75%), sendo os valores mínimo de 0.90 e máximo de 15.50;
# - A maioria dos valores da coluna 'chlorides' varia entre 0.07 (25%) 0.09 (75%), sendo os valores mínimo de 0.05 e máximo de 0.61;
# - A maioria dos valores da coluna 'free sulfur dioxide' varia entre 7.00 (25%) 21.00 (75%), sendo os valores mínimo de 1.00 e máximo de 72.00;
# - A maioria dos valores da coluna 'total sulfur dioxide' varia entre 22.00 (25%) 63.00 (75%), sendo os valores mínimo de 6.00 e máximo de 289.00;
# - A maioria dos valores da coluna 'density' varia entre 0.996 (25%) 0.997 (75%), sendo os valores mínimo de 0.99 e máximo de 1.00;
# - A maioria dos valores da coluna 'pH' varia entre 3.21 (25%) 3.40 (75%), sendo os valores mínimo de 2.74 e máximo de 4.01;
# - A maioria dos valores da coluna 'sulphates' varia entre 0.55 (25%) 0.73 (75%), sendo os valores mínimo de 0.33 e máximo de 2.00;
# - A maioria dos valores da coluna 'alcohol' varia entre 9.50 (25%) 11.10 (75%), sendo os valores mínimo de 8.40 e máximo de 14.90;
# - A maioria dos valores da coluna 'quality' varia entre 5.00 (25%) 6.00 (75%), sendo os valores mínimo de 4.00 e máximo de 8.00;
#
# ### Interpretação global dos resultados:
# - Na maior parte das colunas como, por exemplo, nas colunas 'citric acid', 'density' e 'pH', não existe uma variação muito elevada entre os valores dos percentis com os valores mínimos e máximos;
# - Na coluna 'total sulfur dioxide', existe uma variação tanto entre os percentis de 25% e 75% como entre estes e os valores mínimos e máximos. É preciso analisar melhor esta variação, mas primeiro vamos repetir este processo para os vinhos tintos.

# %%
# Estatísticas descritivas para vinhos tintos
print("Estatísticas descritivas para vinhos tintos")
print(df[df['type'] == 1].describe())
# Out:
# Estatísticas descritivas para vinhos tintos
#          type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# count  4684.0    4684.000000       4684.000000  4684.000000     4684.000000
# mean      1.0       6.852124          0.276394     0.331080        6.325907
# std       0.0       0.823229          0.097004     0.113077        4.886001
# min       1.0       3.900000          0.080000     0.000000        0.600000
# 25%       1.0       6.300000          0.210000     0.270000        1.700000
# 50%       1.0       6.800000          0.260000     0.320000        5.200000
# 75%       1.0       7.300000          0.320000     0.380000        9.800000
# max       1.0      10.700000          0.815000     0.740000       19.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4684.000000          4684.000000           4684.000000  4684.000000
# mean      0.044112            34.663535            137.351196     0.993966
# ...

# %% [markdown]
# ### Interpretação dos resultados detalhados:
# - Existem 4845 linhas com dados referentes a vinhos tintos. Com isto, podemos concluir que o dataset é desbalanceado, uma vez que apresenta uma quantidade de dados relativos aos vinhos tintos bastante superior à quantidade de dados relativos aos vinhos brancos;
# - A maioria dos valores da coluna 'fixed acidity' varia entre 6.30 (25%) 7.30 (75%), sendo os valores mínimo de 3.80 e máximo de 14.20;
# - A maioria dos valores da coluna 'volatile acidity' varia entre 0.21 (25%) 0.32 (75%), sendo os valores mínimo de 0.08 e máximo de 1.10;
# - A maioria dos valores da coluna 'citric acid' varia entre 0.27 (25%) 0.39 (75%), sendo os valores mínimo de 0.00 e máximo de 1.66;
# - A maioria dos valores da coluna 'residual sugar' varia entre 1.70 (25%) 9.90 (75%), sendo os valores mínimo de 0.60 e máximo de 65.80;
# - A maioria dos valores da coluna 'chlorides' varia entre 0.04 (25%) 0.05 (75%), sendo os valores mínimo de 0.01 e máximo de 0.35;
# - A maioria dos valores da coluna 'free sulfur dioxide' varia entre 23.00 (25%) 46.00 (75%), sendo os valores mínimo de 2.00 e máximo de 138.00;
# - A maioria dos valores da coluna 'total sulfur dioxide' varia entre 108.00 (25%) 167.00 (75%), sendo os valores mínimo de 9.00 e máximo de 344.00;
# - A maioria dos valores da coluna 'density' varia entre 0.992 (25%) 0.996 (75%), sendo os valores mínimo de 0.987 e máximo de 1.04;
# - A maioria dos valores da coluna 'pH' varia entre 3.09 (25%) 3.28 (75%), sendo os valores mínimo de 2.72 e máximo de 3.82;
# - A maioria dos valores da coluna 'sulphates' varia entre 0.41 (25%) 0.55 (75%), sendo os valores mínimo de 0.22 e máximo de 1.08;
# - A maioria dos valores da coluna 'alcohol' varia entre 9.50 (25%) 11.40 (75%), sendo os valores mínimo de 8.00 e máximo de 14.20;
# - A maioria dos valores da coluna 'quality' varia entre 5.00 (25%) 6.00 (75%), sendo os valores mínimo de 4.00 e máximo de 8.00;
#
# ### Interpretação global dos resultados:
# - À semelhança do que foi aconteceu na análise dos vinhos brancos, a maior parte das colunas como, por exemplo, nas colunas 'citric acid', 'density' e 'pH', não existe uma variação muito elevada entre os valores dos percentis com os valores mínimos e máximos;
# - Na coluna 'total sulfur dioxide', existe uma variação tanto entre os percentis de 25% e 75% como entre estes e os valores mínimos e máximos. É preciso analisar melhor esta variação, mas primeiro vamos fazer uma análise comparativa entre os dois tipos de vinho.

# %% [markdown]
# ### Análise comparativa dos vinhos brancos e vinhos tintos
# - 'fixed acidity': Os vinhos brancos tendem a ter uma acidez fixa maior que os vinhos tintos.;
# - 'volatile acidity': Os vinhos brancos têm uma acidez volátil maior em média em comparação aos vinhos tintos;
# - 'citric acidity': Os vinhos tintos têm uma maior concentração média de ácido cítrico em comparação aos vinhos brancos;
# - 'residual sugar': Os vinhos tintos têm uma variação maior e geralmente mais açúcar residual comparado aos vinhos brancos;
# - 'chlorides': Os vinhos brancos tendem a ter uma concentração média maior de cloretos do que os vinhos tintos;
# - 'free sulfur dioxide': Os vinhos tintos tendem a ter uma concentração maior de dióxido de enxofre livre em comparação aos vinhos brancos;
# - 'total sulfur dioxide': Os vinhos tintos apresentam uma maior concentração de dióxido de enxofre total em comparação aos vinhos brancos;
# - 'density': Os vinhos brancos têm uma densidade ligeiramente maior que os vinhos tintos;
# - 'pH': Os vinhos brancos tendem a ter um pH ligeiramente mais alto, indicando que são um pouco menos ácidos do que os vinhos tintos;
# - 'sulphates': Os vinhos brancos têm uma concentração média maior de sulfatos do que os vinhos tintos;
# - 'alcohol': Os níveis de álcool são bastante semelhantes entre vinhos brancos e tintos, tendo uma distribuição um pouco mais ampla nos vinhos tintos;
# - 'quality': A qualidade dos vinhos brancos e tintos é bastante semelhante, com uma distribuição concentrada entre 5 e 6.
#
# Podemos agora proceder à análise da relação entre os tipos de vinhos e o atributo 'total sulfur dioxide'

# %%
# comparação dos tipos de vinho com a quantidade total de dióxido de enxofre
white = df[df['type'] == 0]
red = df[df['type'] == 1]

white['total sulfur dioxide'].plot.hist(weights = np.ones(len(white['total sulfur dioxide'])) / len(white['total sulfur dioxide']) * 100,
                                        alpha = 0.5,
                                        color = 'blue',
                                        bins = 60,
                                        ylabel = 'percentagem de vinhos',
                                        xlabel = 'quantidade total de dióxido de enxofre (mg/L)')
red['total sulfur dioxide'].plot.hist(weights = np.ones(len(red['total sulfur dioxide'])) / len(red['total sulfur dioxide']) * 100,
                                      alpha = 0.5,
                                      color = 'red',
                                      bins = 60,
                                      ylabel = 'percentagem de vinhos',
                                      xlabel = 'quantidade total de dióxido de enxofre (mg/L)')

plt.title('Comparação de Quantidade Total de Dióxido de Enxofre entre Vinhos Brancos e Tintos')
plt.legend(['Branco', 'Tinto'])
plt.show()

# %% [markdown]
# ### Interpretação dos resultados obtidos:
# - Apesar de haver um intervalo no qual ambos os tipos de vinhos apresentam valores em comum, existe uma percentagem muito maior de vinhos brancos com valores de quantidade total de dióxido de enxofre mais baixos do que de vinhos tintos e vice-versa. Assim, conclui-se que os vinhos tintos geralmente apresentam quantidade total de dióxido de enxofre superior aos vinhos brancos.
#
# Vamos analisar agora a correlação dos diferentes atributos com a qualidade do vinho. Esta análise vai ser importante para a criação dos modelos de regressão.

# %%
# calcular correlação das variáveis com 'quality' e ordenar em ordem decrescente
corr_with_quality = df.corr()['quality'].sort_values(ascending=False)

# análise de correlação
plt.figure(figsize=(10, 8))
sns.barplot(x=corr_with_quality.values, y=corr_with_quality.index, palette='viridis')
plt.xlabel('Correlação')
plt.ylabel('Variáveis')
plt.title('Correlação das Variáveis com a Qualidade do Vinho')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# ### Interpretação dos resultados obtidos:
# - Os atributos que têm uma maior correlação com a qualidade percebida são o teor de álcool ('alcohol') e o tipo de vinho ('type'). Quanto ao teor de álcool, o valor obtido sugere que quanto maior o teor de álcool, melhor a qualidade percebida. Quanto ao tipo de vinho, embora a correlação seja significativamente menor que a analisada antes, o valor obtido sugere que o tipo de vinho tem relevância na determinação da qualidade percebida;
# - Os atributos que têm uma menor correlação com a qualidade percebida são a densidade ('density'), a quantidade de cloretos ('chlorides') e a acidez volátil ('volatile acidity'). Quanto à densidade, o valor obtido mostra que vinhos com uma densidade mais baixa podem estar associados a uma melhor qualidade percebida. Quanto à quantidade de cloretos e de acidez volátil, os valores obtidos mostram que valores elevados de cloretos e de acidez volátil contribuem negativamente para a qualidade percebida.

# %% [markdown]
# # Pré-processamento

# %% [markdown]
# ## Modelos de Classificação
# ### Objetivo: Desenvolver modelos de classificação que permitam prever corretamente o tipo de vinho.
# Uma vez que os valores de qualidade ('quality') de ambos os tipos de vinhos são bastante semelhantes, podemos remover esta coluna antes de proceder à criação dos modelos.
#
# Para analisar a capacidade de previsão dos diferentes modelos criados (Decision Tree Classifier, Random Forest Classifier e SVC), vão ser avaliados os seguintes parâmetros:
# - Accuracy: mede a proporção de previsões feitas corretamente em comparação ao número total de previsões. Os valores variam entre 0 e 1. Quanto mais próximo de 1, onde 1 representa uma taxa de precisão ideal (100%);
# - F1-Score: representa a média entre a precisão (precision) e recall. Este parâmetro é importante na análise de modelos com base no dataset a ser utilizado uma vez que toma em consideração desbalanceamentos de dados que possam ocorrer. Durante a fase de análise de dados, foi evidenciado que o dataset continha um número bastante superior de informação relativa aos vinhos tintos do que de vinhos brancos;
# - Precision: mede a proporção de verdadeiros positivos em comparação ao número de todas as amostras previstas como positivas (verdadeiros positivos e falsos positivos);
# - Recall: mede a proporção de verdadeiros positivos em comparação ao número de todas as amostras realmente positivas (verdadeiros positivos e falsos negativos).

# %%
# definição das variáveis X (atributos) e y (tipo de vinho)
X = df.drop(columns=['quality', 'type'], axis=1)
y = df['type']

# %%
# divisão dos valores a serem utilizados para teste e treino
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=24)

# %%
# função para avaliar accuracy, f1-score, precision e recall
def evaluateClassification (reais, previstos):
    _accuracy = accuracy_score(reais, previstos)
    _f1 = f1_score(reais, previstos, average='weighted')
    _precision = precision_score(reais, previstos, average='weighted')
    _recall = recall_score(reais, previstos, average='weighted')
    return round(_accuracy,2), round(_f1,2), round(_precision,2), round(_recall,2)

# função para imprimir os valores obtidos na função evaluateClassification
def print_evaluateClassification(model, reais, previstos):
    accuracy, f1, precision, recall = evaluateClassification(reais, previstos)
    print("------------------------------------------")
    print("Accuracy: ", accuracy)
    print("F1-Score: ", f1)
    print("Precision: ", precision)
    print("Recall: ", recall)
    print("------------------------------------------")
    
    results=np.array([model, accuracy, f1, precision, recall])
    results_classification.loc[len(results_classification)+1]= results

# criação da tabela para armazenar os valores obtidos 
results_classification = pd.DataFrame(columns=['Model', 'Accuracy','F1','Precision','Recall'])

# %% [markdown]
# ## - Modelo de Classificação 1: Decision Tree Classifier

# %%
# criação do modelo de classificação Decision Trees (DTC)
dtc = tree.DecisionTreeClassifier(criterion='entropy', max_depth=5, random_state=24)

# treino do modelo DTC
dtc = dtc.fit(X_train, y_train)

# %%
# previsão do modelo DTC
dtc_pred = dtc.predict(X_test)

# %%
# avaliação de accuracy, f1-score, precision e recall do modelo DTC
print('Decision Tree Classifier')
print_evaluateClassification('Decision Tree Classifier', y_test, dtc_pred)
# Out:
# Decision Tree Classifier
# ------------------------------------------
# Accuracy:  0.98
# F1-Score:  0.98
# Precision:  0.98
# Recall:  0.98
# ------------------------------------------

# %% [markdown]
# ### Interpretação dos resultados obtidos:
# - Os valores de avaliação foram bastante altos (0.98), o que significa que o modelo é adequado à previsão do tipo de vinho. No entanto, podemos proceder a uma otimização para descobrir se é possível melhorar o modelo ou não.

# %%
# procurar quais são os melhores parâmetros para poder fazer a otimização
parameters = {
    'max_depth': (4, 6, 9),
    'min_samples_leaf': (1, 8),
    'min_samples_split': (2, 5, 10)
}

grid_search = GridSearchCV(dtc, parameters, n_jobs = -1, verbose = 1, scoring = 'f1')
grid_search.fit(X_train, y_train)

print('Best parameters:')

best_parameters = grid_search.best_estimator_.get_params()

for param_name in sorted(parameters.keys()):
    print('\t%s: %r' % (param_name, best_parameters[param_name]))
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# Best parameters:
# 	max_depth: 6
# 	min_samples_leaf: 1
# 	min_samples_split: 10

# %%
# criação do modelo DTC otimizado
dtc2 = tree.DecisionTreeClassifier(criterion='entropy', random_state=24, max_depth=6, min_samples_leaf=1, min_samples_split=10)

# treino do modelo DTC otimizado
dtc2 = dtc2.fit(X_train, y_train)

# %%
# previsão do modelo DTC otimizado
dtc2_pred = dtc2.predict(X_test)

# %%
# avaliação de accuracy, f1-score, precision e recall do modelo DTC otimizado
print('Decision Tree Classifier')
print_evaluateClassification('Decision Tree Classifier Otimizado', y_test, dtc2_pred)
# Out:
# Decision Tree Classifier
# ------------------------------------------
# Accuracy:  0.98
# F1-Score:  0.98
# Precision:  0.98
# Recall:  0.98
# ------------------------------------------

# %% [markdown]
# ### Interpretação dos resultados obtidos:
# - Apesar de se ter procedido a um processo de otimização do modelo DTC inicial, os valores obtidos foram os mesmos. Contudo, convém realçar que estes valores continuam a favorecer a escolha deste modelo para prever os tipos de vinho.

# %% [markdown]
# ## - Modelo de Classificação 2: Random Forest Classifier

# %%
# criação do modelo de classificação Random Forest (RFC)
rfc = RandomForestClassifier(random_state = 24)

# treino do modelo RFR
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=24)

# %%
# previsão do modelo RFC 
rfc_pred = rfc.predict(X_test)

# %%
# avaliação de accuracy, f1-score, precision e recall do modelo RFC
print('Random Forest Classifier')
print_evaluateClassification('Random Forest Classifier', y_test, rfc_pred)
# Out:
# Random Forest Classifier
# ------------------------------------------
# Accuracy:  0.99
# F1-Score:  0.99
# Precision:  0.99
# Recall:  0.99
# ------------------------------------------

# %% [markdown]
# ### Interpretação dos resultados obtidos:
# - À semelhança do que ocorreu no modelo DTC, os valores de avaliação foram bastante altos (0.99), o que significa que o modelo é adequado à previsão do tipo de vinho. No entanto, podemos proceder a uma otimização para descobrir se é possível melhorar o modelo ou não.

# %%
# procurar quais são os melhores parâmetros para poder fazer a otimização
rfc_params = {'max_depth': [None, 3, 5, 10],
             'max_features': ['sqrt', 'log2', None],
             'n_estimators': [2, 5, 10, 100, 200],
             'min_samples_split': [2, 5, 10]
}

rfc_cv_model = GridSearchCV(RandomForestClassifier(random_state = 24), rfc_params, cv=10, n_jobs = 1, verbose = 1)
rfc_cv_model.fit(X_train, y_train)

print('Best parameters:')
rfc_cv_model.best_params_
# Out:
# Fitting 10 folds for each of 180 candidates, totalling 1800 fits
# Best parameters:
# {'max_depth': None,
#  'max_features': 'sqrt',
#  'min_samples_split': 2,
#  'n_estimators': 200}

# %%
# criação do modelo RFC otimizado
rfc2 = RandomForestClassifier(
    n_estimators = rfc_cv_model.best_params_['n_estimators'],
    max_depth = rfc_cv_model.best_params_['max_depth'],
    max_features = rfc_cv_model.best_params_['max_features'],
    min_samples_split = rfc_cv_model.best_params_['min_samples_split']
)

# treino do modelo RFC otimizado
rfc2.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
# previsão do modelo RFC otimizado
rfc2_pred = rfc2.predict(X_test)

# %%
# avaliação de accuracy, f1-score, precision e recall do modelo RFC otimizado
print('Random Forest Classifier Otimizado')
print_evaluateClassification('Random Forest Classifier Otimizado', y_test, rfc2_pred)
# Out:
# Random Forest Classifier Otimizado
# ------------------------------------------
# Accuracy:  0.99
# F1-Score:  0.99
# Precision:  0.99
# Recall:  0.99
# ------------------------------------------

# %% [markdown]
# ### Interpretação dos resultados obtidos:
# - Apesar de se ter procedido a um processo de otimização do modelo RFC inicial, os valores obtidos foram os mesmos. Contudo, convém realçar que estes valores continuam a favorecer a escolha deste modelo para prever os tipos de vinho.

# %% [markdown]
# ## - Modelo de Classificação 3: SVC

# %%
# criação do modelo Scalable Vector Classifier (SVC)
svc = SVC()

# treino do modelo SVC
svc = svc.fit(X_train, y_train)

# %%
# previsão do modelo SVC
svc_pred = svc.predict(X_test)

# %%
# avaliação de accuracy, f1-score, precision e recall do modelo SVC
print('SVC')
print_evaluateClassification('SVC', y_test, svc_pred)
# Out:
# SVC
# ------------------------------------------
# Accuracy:  0.94
# F1-Score:  0.93
# Precision:  0.94
# Recall:  0.94
# ------------------------------------------

# %% [markdown]
# ### Interpretação dos resultados obtidos:
# - Os valores no modelo SVC foram consideravelmente elevados, sendo o mais baixo 0.93 referente a F1. Uma vez que os valores obtidos foram inferiores aos dos modelos anteriores e como os modelos anteriores obtiveram valores quase ideais (0.99), não há necessidade de realizar otimização deste modelo.

# %%
results_classification
# Out:
#                                 Model Accuracy    F1 Precision Recall
# 1            Decision Tree Classifier     0.98  0.98      0.98   0.98
# 2  Decision Tree Classifier Otimizado     0.98  0.98      0.98   0.98
# 3            Random Forest Classifier     0.99  0.99      0.99   0.99
# 4  Random Forest Classifier Otimizado     0.99  0.99      0.99   0.99
# 5                                 SVC     0.94  0.93      0.94   0.94

# %% [markdown]
# ## - Conclusão
# - Todos os modelos obtiveram valores de accuracy, f1-score, precision e recall elevados, estando estes valores compreendidos entre 0.93-0.99;
# - O modelo que obteve melhores resultados foi o Random Forest Classifier, tendo a versão otimizado deste modelo obtido os mesmos resultados. Assim, conclui-se que este é o modelo mais adequada para a previsão dos tipos de vinho.

# %% [markdown]
# ## Modelos de Regressão
# ### Objetivo: Desenvolver modelos de regressão que permitam prever a qualidade do vinho.
# Uma vez que o atributo 'quality' é importante para esta análise, é necessário fazer uma nova definição dos valores atribuídos às variáveis X e y
#
# Para analisar a capacidade de previsão dos diferentes modelos criados (Linear Regression, Random Forest Regressor e XGBoost), vão ser avaliados os seguintes parâmetros:
# - MAE (Mean Absolute Error): representa a média dos erros absolutos entre os valores previstos e os valores reais. Quanto menor o MAE, melhor o desempenho do modelo;
# - MSE (Mean Square Error): representa a média dos erros elevados ao quadrado entre os valores previstos e os valores reais. O MSE penaliza os erros mais severamente que o MAE devido a elevá-los ao quadrado;
# - RMSE (Root Mean Squared Error): representa a raiz da quadrado do MSE, aproximando os valores dos erros obtidos da escala dos valores reais;
# - R2 (Coefficient of Determination): mede a proporção da variabilidade nos dados de resposta dados pelos modelos, podendo este valor variar entre 0 e 1. Quanto mais próximo de 1, melhor é a capacidade de previsão do modelo.

# %%
# definição das variáveis X (atributos) e y (tipo de vinho)
X = df.drop(columns=['quality'], axis=1)
y = df['quality']

# %%
# divisão dos valores a serem utilizados para teste e treino
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=24)

# %%
# função para avaliar os erros (MAE, MSE, RMSE, R2) de cada modelo
def evaluate (reais, previstos):
    _mae=mae(reais, previstos)
    _mse=mse(reais, previstos)
    _rmse=np.sqrt(_mse)
    _r2=r2_score(reais, previstos)
    return round(_mae,2), round(_mse,2), round(_rmse,2), round(_r2,2)

# função para imprimir os valores obtidos na função de avaliação 
def print_evaluateRegression(model, reais, previstos):
    mae, mse, rmse, r2 = evaluate(reais,previstos)
    print("------------------------------------------")
    print("MAE:", mae)
    print("MSE:", mse)
    print("RMSE:", rmse)
    print("R2 score:", r2)
    print("------------------------------------------")
    
    results=np.array([model,mae,mse,rmse,r2])
    results_regression.loc[len(results_regression)+1]= results

# criação da tabela para armazenar os valores obtidos 
results_regression = pd.DataFrame(columns=['Model', 'MAE','MSE','RMSE','R2'])

# %% [markdown]
# ## - Modelo de Regressão 1: Linear Regression

# %%
# criação do modelo Linear Regression (LR)
lr = LinearRegression()

# treino do modelo criado
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# previsão do modelo LR
lr_pred = lr.predict(X_test)

# %%
# avaliação de MAE, MSE, RMSE e R2 do modelo LR
print('Linear Regression')
print_evaluateRegression('Linear Regression', y_test, lr_pred)
# Out:
# Linear Regression
# ------------------------------------------
# MAE: 0.54
# MSE: 0.47
# RMSE: 0.69
# R2 score: 0.3
# ------------------------------------------

# %% [markdown]
# ### Interpretação dos resultados obtidos:
# - Os valores de MAE, MSE e RMSE nem são muito elevados nem muito baixos, sendo o valor mais alto de 0.69 referente a RMSE. Isto faz com que o modelo de Linear Regression apresente um grau considerável de previsão de erro, podendo existir outros modelos mais adequados ao que é pretendido;
# - O valor de R2 é relativamente baixo (0.3), o que significa que o modelo não explica bem a variação dos dados consoante os diferentes atributos do dataset.

# %% [markdown]
# ## - Modelo de Regressão 2: Random Forest Regressor

# %%
# criação do modelo Random Forest Regressor (RFR)
rfr = RandomForestRegressor(random_state=24)

# treino do modelo criado
rfr.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=24)

# %%
# previsão do modelo RFR
rfr_pred = rfr.predict(X_test)

# %%
# avaliação de MAE, MSE, RMSE e R2 do modelo RFR
print('Random Forest Regressor')
print_evaluateRegression('Random Forest Regressor', y_test, rfr_pred)
# Out:
# Random Forest Regressor
# ------------------------------------------
# MAE: 0.42
# MSE: 0.33
# RMSE: 0.57
# R2 score: 0.51
# ------------------------------------------

# %% [markdown]
# ### Interpretação dos resultados obtidos:
# - À semelhança do modelo de Linear Regression, os valores de MAE, MSE e RMSE obtidos no modelo de Random Forest Regressor não são muito elevados, nem muito baixos. No entanto, este modelo apresenta um valor de MSE mais baixos, o que significa que este modelo tem um maior grau de precisão;
# - Em comparação ao modelo de Linear Regression, o modelo de Random Forest apresenta um melhor resultado de R2, o que indica que este modelo tem uma melhor capacidade de previsão;
# - Apesar dos valores serem melhores do que os do modelo anterior, vamos proceder a um processo de otimização para descobrir se conseguimos melhorar os resultados obtidos com este modelo.

# %%
# procurar quais são os melhores parâmetros para poder fazer a otimização
rfr_params = {'max_depth': [None, 3, 5, 10],
             'max_features': ['sqrt', 'log2', None],
             'n_estimators': [2, 5, 10, 100, 200],
             'min_samples_split': [2, 5, 10]
}

rfr_cv_model = GridSearchCV(RandomForestRegressor(random_state = 24), rfr_params, cv=10, n_jobs = 1, verbose = 1)
rfr_cv_model.fit(X_train, y_train)

print('Best parameters:')
rfr_cv_model.best_params_
# Out:
# Fitting 10 folds for each of 180 candidates, totalling 1800 fits
# Best parameters:
# {'max_depth': None,
#  'max_features': 'sqrt',
#  'min_samples_split': 2,
#  'n_estimators': 200}

# %%
# criação do modelo RFR otimizado
rfr2 = RandomForestRegressor(
    n_estimators = rfr_cv_model.best_params_['n_estimators'],
    max_depth = rfr_cv_model.best_params_['max_depth'],
    max_features = rfr_cv_model.best_params_['max_features'],
    min_samples_split = rfr_cv_model.best_params_['min_samples_split']
)

# treino do modelo RFR otimizado
rfr2.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_features='sqrt', n_estimators=200)

# %%
# previsão do modelo RFR otimizado
rfr2_pred = rfr2.predict(X_test)

# %%
# avaliação de MAE, MSE, RMSE e R2 do modelo RFR
print('Random Forest Regressor Otimizado')
print_evaluateRegression('Random Forest Regressor Otimizado', y_test, rfr2_pred)
# Out:
# Random Forest Regressor Otimizado
# ------------------------------------------
# MAE: 0.41
# MSE: 0.31
# RMSE: 0.56
# R2 score: 0.54
# ------------------------------------------

# %% [markdown]
# ### Interpretação dos resultados obtidos:
# - Os valores de MAE, MSE e RMSE melhoraram ligeiramente, o que significa que há uma redução de erro durante as previsões feitas pelo modelo;
# - Quanto ao valor de R2, também ocorreu uma melhoria mínima, fazendo com que o modelo de Random Forest otimizado tenha uma melhor capacidade de previsão do que o modelo não otimizado.

# %% [markdown]
# ## - Modelo de Regressão 3: XGBoost

# %%
# criação do modelo XGBoost (XGB)
xgb = XGBRegressor()

# treino do modelo XGB
xgb.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
# previsão do modelo XGB 
xgb_pred = xgb.predict(X_test)

# %%
# avaliação de MAE, MSE, RMSE e R2 do modelo XGB
print('XGBoost')
print_evaluateRegression('XGBoost', y_test, xgb_pred)
# Out:
# XGBoost
# ------------------------------------------
# MAE: 0.44
# MSE: 0.36
# RMSE: 0.6
# R2 score: 0.46
# ------------------------------------------

# %% [markdown]
# ### Interpretação dos resultados obtidos:
# - Em relação aos valores de MAE, MSE e RMSE, o modelo de XGBoost obteve piores resultados do que os modelos de Random Forest (otimizado e não otimizado), mas ligeiramente melhores resultados do que o modelo de Linear Regression;
# - O valor de R2 é próximo do valor obtido no mesmo parâmetro no modelo de Random Forest não otimizado, por isso vamos proceder a otimização do processo para descobrir se conseguimos melhorar este modelo e possivelmente torná-lo mais adequado do que os modelos de Random Forest.

# %%
# procurar quais são os melhores parâmetros para poder fazer a otimização
xgb_params = {
    'booster': ['gbtree', 'gblinear'],
    'learning_rate': [0.01, 0.1],
    'n_estimators': [100, 500],
    'objective': ['reg:squarederror']
}

xgb_cv_model = GridSearchCV(XGBRegressor(random_state=24), xgb_params, cv=10, n_jobs=-1, verbose=1) 
xgb_cv_model.fit(X_train, y_train)

print('Best parameters:')
xgb_cv_model.best_params_
# Out:
# Fitting 10 folds for each of 8 candidates, totalling 80 fits
# Best parameters:
# {'booster': 'gbtree',
#  'learning_rate': 0.1,
#  'n_estimators': 500,
#  'objective': 'reg:squarederror'}

# %%
# criação do modelo XGB otimizado
xgb2 = XGBRegressor(
    booster = xgb_cv_model.best_params_['booster'],
    learning_rate = xgb_cv_model.best_params_['learning_rate'],
    n_estimators = xgb_cv_model.best_params_['n_estimators'],
    objective = xgb_cv_model.best_params_['objective']
)

# treino do modelo XGB otimizado
xgb2.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=500, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
# avaliação de MAE, MSE, RMSE e R2 do modelo XGB otimizado
print('XGBoost Otimizado')
print_evaluateRegression('XGBoost Otimizado', y_test, xgb_pred)
# Out:
# XGBoost Otimizado
# ------------------------------------------
# MAE: 0.44
# MSE: 0.36
# RMSE: 0.6
# R2 score: 0.46
# ------------------------------------------

# %% [markdown]
# ### Interpretação dos resultados obtidos:
# - Os valores de MAE, MSE e RMSE obtidos no modelo otimizado foram iguais aos valores obtidos no modelo não otimizado, o que significa que a otimização não conseguiu melhorar o modelo de XGBoost;
# - Também o valor de R2 permaneceu igual. Deste modo, conclui-se que a otimização não melhorou a capacidade de previsão do modelo de XGBoost.

# %%
results_regression
# Out:
#                                Model   MAE   MSE  RMSE    R2
# 1                  Linear Regression  0.54  0.47  0.69   0.3
# 2            Random Forest Regressor  0.42  0.33  0.57  0.51
# 3  Random Forest Regressor Otimizado  0.41  0.31  0.56  0.54
# 4                            XGBoost  0.44  0.36   0.6  0.46
# 5                  XGBoost Otimizado  0.44  0.36   0.6  0.46

# %% [markdown]
# ### Interpretação dos resultados obtidos:
# - O modelo mais adequado para a previsão dos fatores químicos que mais influenciam na qualidade percebida do vinho é o modelo de Random Forest Regressor otimizado, dado ter sido o modelo com valores de MAE, MSE e RMSE mais baixos e o coeficiente de R2 mais alto, sendo este último indicativo de um melhor grau de previsão;
# - O modelo com a pior previsão de erro (R2) foi o modelo de Linear Regression, em que o valor obtido foi 0,2 mais baixo do que o valor obtido no melhor modelo.
